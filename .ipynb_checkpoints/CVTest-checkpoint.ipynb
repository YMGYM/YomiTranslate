# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract as pyt

# %%
print(pyt.image_to_string(Image.open('TestFile/en_xs.jpg')))
# Out:
# THESE
#
# YS,
# “SCRAWNY"
# MEANS A
# GUY WHO'S
# KIND AND
# GENTLE

# %%
import cv2

# %%
image = cv2.imread('TestFile/en_xs.jpg')

# %%
ret, thes = cv2.threshold(image, 105, 255, cv2.THRESH_BINARY)

# %%
import matplotlib.pyplot as plt

# %%
# plt.subplots(figsize = (100,100))
plt.imshow(thes, 'gray')

# %%
print(pyt.image_to_string(thes))
# Out:
# THESE
# DAYS,
# “SCRAWNY™
# MEANS A
# GUY WHO'S
# KIND AND
# GENTLE

# %%
jpn_image = cv2.imread('TestFile/jp_xs.jpg')

# %%
ret, thes = cv2.threshold(image, 200, 255, cv2.THRESH_BINARY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-205-d855c495cf69> in <module>
# ----> 1 ret, thes = cv2.threshold(image, 200, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
#
# error: OpenCV(4.4.0) /private/var/folders/nz/vv4_9tw56nv9k3tkvyszvwg80000gn/T/pip-req-build-b4ibzwe2/opencv/modules/imgproc/src/thresh.cpp:1557: error: (-2:Unspecified error) in function 'double cv::threshold(cv::InputArray, cv::OutputArray, double, double, int)'
# > THRESH_OTSU mode:
# >     'src_type == CV_8UC1 || src_type == CV_16UC1'
# > where
# >     'src_type' is 16 (CV_8UC3)

# %%
plt.imshow(jpn_image, 'gray')

# %%
print(pyt.image_to_string(thes, lang='jpn_vert'))
